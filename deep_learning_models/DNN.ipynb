# %%
from tensorflow.keras.models import Sequential
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, roc_auc_score, precision_recall_curve, roc_curve, auc
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# CSV 파일 불러오기
single_data = pd.read_csv("../merged_dataset/single_train/single_train.csv")
single_test_data = pd.read_csv("../extracted_keypoints/jumprope_test/sj_type1_9.csv")

double_data = pd.read_csv("../merged_dataset/double_train/double_train.csv")
double_test_data = pd.read_csv("../extracted_keypoints/quickly_test/sj_type2_7.csv")

# %%
# 'Frame'열을 제외한 모든 열 선택
feature_columns = single_data.columns[1:-1]

# 입력 데이터(X)와 레이블(Y) 분리
X_single = single_data[feature_columns].values
Y_single = single_data['Label'].values

X_single_test = single_test_data[feature_columns].values
Y_single_test = single_test_data['Label'].values



# standardscaler로 데이터 정규화
single_scaler = StandardScaler()
single_scaler_test = StandardScaler()


X_single = single_scaler.fit_transform(X_single)
X_single_test = single_scaler_test.fit_transform(X_single_test)


X_single=X_single.astype(int)
Y_single=Y_single.astype(int)

X_single_test=X_single_test.astype(int)
Y_single_test=Y_single_test.astype(int)

# %%
# 'Frame'열을 제외한 모든 열 선택
feature_columns = double_data.columns[1:-1]

# 입력 데이터(X)와 레이블(Y) 분리
X_double = double_data[feature_columns].values
Y_double = double_data['Label'].values

X_double_test = double_test_data[feature_columns].values
Y_double_test = double_test_data['Label'].values



# standardscaler로 데이터 정규화
double_scaler = StandardScaler()
double_scaler_test = StandardScaler()


X_double = double_scaler.fit_transform(X_double)
X_double_test = double_scaler_test.fit_transform(X_double_test)


X_double=X_double.astype(int)
Y_double=Y_double.astype(int)

X_double_test=X_double_test.astype(int)
Y_double_test=Y_double_test.astype(int)

# %%
# train-valid 데이터 분할 (80%, 20%)
X_single_train, X_single_val, Y_single_train, Y_single_val = train_test_split(X_single, Y_single, test_size=0.2, random_state=42)

# %%
# train-valid 데이터 분할 (80%, 20%)
X_double_train, X_double_val, Y_double_train, Y_double_val = train_test_split(X_double, Y_double, test_size=0.2, random_state=42)

# %%
single_model = Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(27,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

double_model = Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(27,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
single_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['Accuracy'])

double_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['Accuracy'])

# %%
eps = 100

# %%
# 데이터 형태 조정 (3D로 변환)
X_single_train_3d = X_single_train.reshape((X_single_train.shape[0], X_single_train.shape[1], 1))
X_single_val_3d = X_single_val.reshape((X_single_val.shape[0], X_single_val.shape[1], 1))

# 데이터 형태 조정 (3D로 변환)
X_double_train_3d = X_double_train.reshape((X_double_train.shape[0], X_double_train.shape[1], 1))
X_double_val_3d = X_double_val.reshape((X_double_val.shape[0], X_double_val.shape[1], 1))

# %%
single_history = single_model.fit(X_single_train_3d, Y_single_train, epochs=eps, batch_size=32, validation_data=(X_single_val_3d, Y_single_val))
# Out:
# Epoch 1/100
# 26/26 [==============================] - 1s 10ms/step - loss: 0.6177 - Accuracy: 0.7075 - val_loss: 0.4975 - val_Accuracy: 0.9317
# Epoch 2/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3978 - Accuracy: 0.9033 - val_loss: 0.2778 - val_Accuracy: 0.9610
# Epoch 3/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.2590 - Accuracy: 0.9253 - val_loss: 0.1866 - val_Accuracy: 0.9610
# Epoch 4/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1997 - Accuracy: 0.9278 - val_loss: 0.1491 - val_Accuracy: 0.9707
# Epoch 5/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1640 - Accuracy: 0.9425 - val_loss: 0.1265 - val_Accuracy: 0.9756
# Epoch 6/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1401 - Accuracy: 0.9486 - val_loss: 0.1179 - val_Accuracy: 0.9707
# Epoch 7/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1252 - Accuracy: 0.9535 - val_loss: 0.1138 - val_Accuracy: 0.9756
# Epoch 8/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1112 - Accuracy: 0.9596 - val_loss: 0.1104 - val_Accuracy: 0.9707
# Epoch 9/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1023 - Accuracy: 0.9633 - val_loss: 0.1119 - val_Accuracy: 0.9707
# Epoch 10/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0965 - Accuracy: 0.9657 - val_loss: 0.1156 - val_Accuracy: 0.9659
# Epoch 11/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0896 - Accuracy: 0.9694 - val_loss: 0.1187 - val_Accuracy: 0.9659
# Epoch 12/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0820 - Accuracy: 0.9718 - val_loss: 0.1202 - val_Accuracy: 0.9659
# Epoch 13/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0759 - Accuracy: 0.9743 - val_loss: 0.1218 - val_Accuracy: 0.9610
# Epoch 14/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0719 - Accuracy: 0.9767 - val_loss: 0.1225 - val_Accuracy: 0.9610
# Epoch 15/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0703 - Accuracy: 0.9804 - val_loss: 0.1260 - val_Accuracy: 0.9610
# Epoch 16/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0667 - Accuracy: 0.9804 - val_loss: 0.1348 - val_Accuracy: 0.9610
# Epoch 17/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0619 - Accuracy: 0.9816 - val_loss: 0.1343 - val_Accuracy: 0.9610
# Epoch 18/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0610 - Accuracy: 0.9829 - val_loss: 0.1408 - val_Accuracy: 0.9610
# Epoch 19/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0612 - Accuracy: 0.9841 - val_loss: 0.1469 - val_Accuracy: 0.9561
# Epoch 20/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0549 - Accuracy: 0.9853 - val_loss: 0.1534 - val_Accuracy: 0.9415
# Epoch 21/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0533 - Accuracy: 0.9853 - val_loss: 0.1518 - val_Accuracy: 0.9561
# Epoch 22/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0516 - Accuracy: 0.9853 - val_loss: 0.1561 - val_Accuracy: 0.9463
# Epoch 23/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0510 - Accuracy: 0.9841 - val_loss: 0.1607 - val_Accuracy: 0.9512
# Epoch 24/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0492 - Accuracy: 0.9865 - val_loss: 0.1607 - val_Accuracy: 0.9512
# Epoch 25/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0471 - Accuracy: 0.9865 - val_loss: 0.1665 - val_Accuracy: 0.9463
# Epoch 26/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0464 - Accuracy: 0.9865 - val_loss: 0.1671 - val_Accuracy: 0.9561
# Epoch 27/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0451 - Accuracy: 0.9865 - val_loss: 0.1724 - val_Accuracy: 0.9512
# Epoch 28/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0445 - Accuracy: 0.9878 - val_loss: 0.1718 - val_Accuracy: 0.9512
# Epoch 29/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0432 - Accuracy: 0.9865 - val_loss: 0.1804 - val_Accuracy: 0.9512
# Epoch 30/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0419 - Accuracy: 0.9890 - val_loss: 0.1828 - val_Accuracy: 0.9561
# Epoch 31/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0427 - Accuracy: 0.9865 - val_loss: 0.1852 - val_Accuracy: 0.9512
# Epoch 32/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0419 - Accuracy: 0.9878 - val_loss: 0.1861 - val_Accuracy: 0.9561
# Epoch 33/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0399 - Accuracy: 0.9878 - val_loss: 0.1918 - val_Accuracy: 0.9463
# Epoch 34/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0406 - Accuracy: 0.9878 - val_loss: 0.1949 - val_Accuracy: 0.9512
# Epoch 35/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0396 - Accuracy: 0.9890 - val_loss: 0.1931 - val_Accuracy: 0.9512
# Epoch 36/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0393 - Accuracy: 0.9878 - val_loss: 0.2013 - val_Accuracy: 0.9512
# Epoch 37/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0423 - Accuracy: 0.9865 - val_loss: 0.2072 - val_Accuracy: 0.9561
# Epoch 38/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0409 - Accuracy: 0.9890 - val_loss: 0.2016 - val_Accuracy: 0.9463
# Epoch 39/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0378 - Accuracy: 0.9890 - val_loss: 0.2058 - val_Accuracy: 0.9512
# Epoch 40/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0376 - Accuracy: 0.9890 - val_loss: 0.2102 - val_Accuracy: 0.9512
# Epoch 41/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0390 - Accuracy: 0.9878 - val_loss: 0.2163 - val_Accuracy: 0.9463
# Epoch 42/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0365 - Accuracy: 0.9878 - val_loss: 0.2138 - val_Accuracy: 0.9512
# Epoch 43/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0383 - Accuracy: 0.9890 - val_loss: 0.2221 - val_Accuracy: 0.9463
# Epoch 44/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0367 - Accuracy: 0.9878 - val_loss: 0.2205 - val_Accuracy: 0.9512
# Epoch 45/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0366 - Accuracy: 0.9878 - val_loss: 0.2243 - val_Accuracy: 0.9512
# Epoch 46/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0358 - Accuracy: 0.9878 - val_loss: 0.2251 - val_Accuracy: 0.9512
# Epoch 47/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0372 - Accuracy: 0.9878 - val_loss: 0.2327 - val_Accuracy: 0.9463
# Epoch 48/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0371 - Accuracy: 0.9890 - val_loss: 0.2299 - val_Accuracy: 0.9415
# Epoch 49/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0370 - Accuracy: 0.9878 - val_loss: 0.2318 - val_Accuracy: 0.9463
# Epoch 50/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0343 - Accuracy: 0.9890 - val_loss: 0.2316 - val_Accuracy: 0.9512
# Epoch 51/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0347 - Accuracy: 0.9890 - val_loss: 0.2427 - val_Accuracy: 0.9415
# Epoch 52/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0354 - Accuracy: 0.9878 - val_loss: 0.2468 - val_Accuracy: 0.9512
# Epoch 53/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0345 - Accuracy: 0.9878 - val_loss: 0.2465 - val_Accuracy: 0.9463
# Epoch 54/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0337 - Accuracy: 0.9890 - val_loss: 0.2495 - val_Accuracy: 0.9463
# Epoch 55/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0342 - Accuracy: 0.9890 - val_loss: 0.2498 - val_Accuracy: 0.9512
# Epoch 56/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0335 - Accuracy: 0.9878 - val_loss: 0.2521 - val_Accuracy: 0.9415
# Epoch 57/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0340 - Accuracy: 0.9890 - val_loss: 0.2530 - val_Accuracy: 0.9512
# Epoch 58/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0329 - Accuracy: 0.9890 - val_loss: 0.2575 - val_Accuracy: 0.9415
# Epoch 59/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0330 - Accuracy: 0.9890 - val_loss: 0.2620 - val_Accuracy: 0.9512
# Epoch 60/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0332 - Accuracy: 0.9890 - val_loss: 0.2601 - val_Accuracy: 0.9463
# Epoch 61/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0326 - Accuracy: 0.9890 - val_loss: 0.2597 - val_Accuracy: 0.9512
# Epoch 62/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0321 - Accuracy: 0.9890 - val_loss: 0.2617 - val_Accuracy: 0.9463
# Epoch 63/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0333 - Accuracy: 0.9890 - val_loss: 0.2685 - val_Accuracy: 0.9415
# Epoch 64/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0319 - Accuracy: 0.9890 - val_loss: 0.2669 - val_Accuracy: 0.9415
# Epoch 65/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0339 - Accuracy: 0.9890 - val_loss: 0.2708 - val_Accuracy: 0.9561
# Epoch 66/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0329 - Accuracy: 0.9890 - val_loss: 0.2769 - val_Accuracy: 0.9366
# Epoch 67/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0315 - Accuracy: 0.9890 - val_loss: 0.2760 - val_Accuracy: 0.9366
# Epoch 68/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0321 - Accuracy: 0.9890 - val_loss: 0.2716 - val_Accuracy: 0.9415
# Epoch 69/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0315 - Accuracy: 0.9878 - val_loss: 0.2746 - val_Accuracy: 0.9512
# Epoch 70/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0319 - Accuracy: 0.9878 - val_loss: 0.2794 - val_Accuracy: 0.9415
# Epoch 71/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0315 - Accuracy: 0.9878 - val_loss: 0.2786 - val_Accuracy: 0.9415
# Epoch 72/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0305 - Accuracy: 0.9890 - val_loss: 0.2832 - val_Accuracy: 0.9415
# Epoch 73/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0324 - Accuracy: 0.9878 - val_loss: 0.2779 - val_Accuracy: 0.9463
# Epoch 74/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0322 - Accuracy: 0.9878 - val_loss: 0.2807 - val_Accuracy: 0.9512
# Epoch 75/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0309 - Accuracy: 0.9890 - val_loss: 0.2828 - val_Accuracy: 0.9415
# Epoch 76/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0339 - Accuracy: 0.9878 - val_loss: 0.2829 - val_Accuracy: 0.9415
# Epoch 77/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0317 - Accuracy: 0.9878 - val_loss: 0.2769 - val_Accuracy: 0.9463
# Epoch 78/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0314 - Accuracy: 0.9890 - val_loss: 0.2847 - val_Accuracy: 0.9561
# Epoch 79/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0331 - Accuracy: 0.9878 - val_loss: 0.2832 - val_Accuracy: 0.9415
# Epoch 80/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0318 - Accuracy: 0.9878 - val_loss: 0.2823 - val_Accuracy: 0.9512
# Epoch 81/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0310 - Accuracy: 0.9878 - val_loss: 0.2860 - val_Accuracy: 0.9415
# Epoch 82/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0323 - Accuracy: 0.9865 - val_loss: 0.2847 - val_Accuracy: 0.9415
# Epoch 83/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0327 - Accuracy: 0.9878 - val_loss: 0.2877 - val_Accuracy: 0.9415
# Epoch 84/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0307 - Accuracy: 0.9878 - val_loss: 0.2884 - val_Accuracy: 0.9561
# Epoch 85/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0317 - Accuracy: 0.9890 - val_loss: 0.2834 - val_Accuracy: 0.9463
# Epoch 86/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0313 - Accuracy: 0.9878 - val_loss: 0.2854 - val_Accuracy: 0.9463
# Epoch 87/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0320 - Accuracy: 0.9865 - val_loss: 0.2844 - val_Accuracy: 0.9512
# Epoch 88/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0312 - Accuracy: 0.9878 - val_loss: 0.2882 - val_Accuracy: 0.9415
# Epoch 89/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0312 - Accuracy: 0.9865 - val_loss: 0.2861 - val_Accuracy: 0.9512
# Epoch 90/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0321 - Accuracy: 0.9890 - val_loss: 0.2864 - val_Accuracy: 0.9463
# Epoch 91/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0319 - Accuracy: 0.9878 - val_loss: 0.2904 - val_Accuracy: 0.9415
# Epoch 92/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0319 - Accuracy: 0.9865 - val_loss: 0.2874 - val_Accuracy: 0.9561
# Epoch 93/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0308 - Accuracy: 0.9890 - val_loss: 0.2845 - val_Accuracy: 0.9463
# Epoch 94/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0315 - Accuracy: 0.9853 - val_loss: 0.2919 - val_Accuracy: 0.9561
# Epoch 95/100
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0322 - Accuracy: 0.9890 - val_loss: 0.2858 - val_Accuracy: 0.9415
# Epoch 96/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0335 - Accuracy: 0.9865 - val_loss: 0.2856 - val_Accuracy: 0.9561
# Epoch 97/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0307 - Accuracy: 0.9890 - val_loss: 0.2817 - val_Accuracy: 0.9512
# Epoch 98/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0297 - Accuracy: 0.9890 - val_loss: 0.2871 - val_Accuracy: 0.9512
# Epoch 99/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0305 - Accuracy: 0.9878 - val_loss: 0.2932 - val_Accuracy: 0.9561
# Epoch 100/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0332 - Accuracy: 0.9853 - val_loss: 0.2869 - val_Accuracy: 0.9561

# %%
double_history = double_model.fit(X_double_train_3d, Y_double_train, epochs=eps, batch_size=32, validation_data=(X_double_val_3d, Y_double_val))
# Out:
# Epoch 1/100
# 28/28 [==============================] - 1s 9ms/step - loss: 0.5711 - Accuracy: 0.6667 - val_loss: 0.4738 - val_Accuracy: 0.7104
# Epoch 2/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.4176 - Accuracy: 0.7710 - val_loss: 0.3778 - val_Accuracy: 0.8009
# Epoch 3/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3593 - Accuracy: 0.8095 - val_loss: 0.3351 - val_Accuracy: 0.8281
# Epoch 4/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3266 - Accuracy: 0.8311 - val_loss: 0.3134 - val_Accuracy: 0.8371
# Epoch 5/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3045 - Accuracy: 0.8537 - val_loss: 0.3068 - val_Accuracy: 0.8552
# Epoch 6/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2813 - Accuracy: 0.8798 - val_loss: 0.2901 - val_Accuracy: 0.8597
# Epoch 7/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2664 - Accuracy: 0.8889 - val_loss: 0.2846 - val_Accuracy: 0.8552
# Epoch 8/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2493 - Accuracy: 0.8946 - val_loss: 0.2833 - val_Accuracy: 0.8552
# Epoch 9/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2384 - Accuracy: 0.8968 - val_loss: 0.2917 - val_Accuracy: 0.8597
# Epoch 10/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2282 - Accuracy: 0.8980 - val_loss: 0.2866 - val_Accuracy: 0.8597
# Epoch 11/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2257 - Accuracy: 0.9002 - val_loss: 0.2931 - val_Accuracy: 0.8597
# Epoch 12/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2155 - Accuracy: 0.9048 - val_loss: 0.3140 - val_Accuracy: 0.8597
# Epoch 13/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.2124 - Accuracy: 0.9025 - val_loss: 0.2861 - val_Accuracy: 0.8462
# Epoch 14/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2182 - Accuracy: 0.9002 - val_loss: 0.3032 - val_Accuracy: 0.8597
# Epoch 15/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2050 - Accuracy: 0.9082 - val_loss: 0.3096 - val_Accuracy: 0.8597
# Epoch 16/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2029 - Accuracy: 0.9093 - val_loss: 0.3123 - val_Accuracy: 0.8552
# Epoch 17/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1981 - Accuracy: 0.9093 - val_loss: 0.3183 - val_Accuracy: 0.8552
# Epoch 18/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1948 - Accuracy: 0.9104 - val_loss: 0.3148 - val_Accuracy: 0.8552
# Epoch 19/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1887 - Accuracy: 0.9172 - val_loss: 0.3437 - val_Accuracy: 0.8552
# Epoch 20/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1863 - Accuracy: 0.9161 - val_loss: 0.3332 - val_Accuracy: 0.8552
# Epoch 21/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1842 - Accuracy: 0.9172 - val_loss: 0.3251 - val_Accuracy: 0.8552
# Epoch 22/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1834 - Accuracy: 0.9127 - val_loss: 0.3286 - val_Accuracy: 0.8552
# Epoch 23/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1898 - Accuracy: 0.9138 - val_loss: 0.3287 - val_Accuracy: 0.8507
# Epoch 24/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1839 - Accuracy: 0.9150 - val_loss: 0.3645 - val_Accuracy: 0.8552
# Epoch 25/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1760 - Accuracy: 0.9150 - val_loss: 0.3583 - val_Accuracy: 0.8597
# Epoch 26/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.
100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1486 - Accuracy: 0.9263 - val_loss: 0.5707 - val_Accuracy: 0.8371
# Epoch 92/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1455 - Accuracy: 0.9263 - val_loss: 0.4896 - val_Accuracy: 0.8507
# Epoch 93/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1491 - Accuracy: 0.9252 - val_loss: 0.4780 - val_Accuracy: 0.8462
# Epoch 94/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1524 - Accuracy: 0.9218 - val_loss: 0.5234 - val_Accuracy: 0.8552
# Epoch 95/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1468 - Accuracy: 0.9229 - val_loss: 0.5386 - val_Accuracy: 0.8507
# Epoch 96/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1474 - Accuracy: 0.9252 - val_loss: 0.5225 - val_Accuracy: 0.8552
# Epoch 97/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1452 - Accuracy: 0.9218 - val_loss: 0.5346 - val_Accuracy: 0.8552
# Epoch 98/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.1483 - Accuracy: 0.9252 - val_loss: 0.5220 - val_Accuracy: 0.8552
# Epoch 99/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1457 - Accuracy: 0.9240 - val_loss: 0.5158 - val_Accuracy: 0.8507
# Epoch 100/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1494 - Accuracy: 0.9229 - val_loss: 0.5032 - val_Accuracy: 0.8507

# %%
# 모델들 학습 및 평가
single_model.fit(X_single_train, Y_single_train)
single_Y_prob = single_model.predict(X_single_test) 
single_auc_score = roc_auc_score(Y_single_test, single_Y_prob)


# 임계값 설정
threshold = 0.5  # 예측된 확률이 0.5 이상이면 클래스를 1로 예측

# 예측된 확률을 클래스 레이블로 변환
single_Y_pred_binary = (single_Y_prob >= threshold).astype(int)

# Precision 계산
single_precision = precision_score(Y_single_test, single_Y_pred_binary)

# Recall 계산
single_recall = recall_score(Y_single_test, single_Y_pred_binary)

# F1 score 계산
single_f1 = f1_score(Y_single_test, single_Y_pred_binary)

# Confusion Matrix 계산
single_conf_matrix = confusion_matrix(Y_single_test, single_Y_pred_binary)

single_accuracy = accuracy_score(Y_single_test, single_Y_pred_binary)
# Out:
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0303 - Accuracy: 0.9878
# 6/6 [==============================] - 0s 1ms/step

# %%
# 모델들 학습 및 평가
double_model.fit(X_double_train, Y_double_train)
double_Y_prob = double_model.predict(X_double_test)
double_auc_score = roc_auc_score(Y_double_test, double_Y_prob)

# 임계값 설정
threshold = 0.5  # 예측된 확률이 0.5 이상이면 클래스를 1로 예측

# 예측된 확률을 클래스 레이블로 변환
double_Y_pred_binary = (double_Y_prob >= threshold).astype(int)

# Precision 계산
double_precision = precision_score(Y_double_test, double_Y_pred_binary)

# Recall 계산
double_recall = recall_score(Y_double_test, double_Y_pred_binary)

# F1 score 계산
double_f1 = f1_score(Y_double_test, double_Y_pred_binary)

# Confusion Matrix 계산
double_conf_matrix = confusion_matrix(Y_double_test, double_Y_pred_binary)

double_accuracy = accuracy_score(Y_double_test, double_Y_pred_binary)
# Out:
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1464 - Accuracy: 0.9252
# 5/5 [==============================] - 0s 1ms/step

# %%
# 결과 출력
print("Single")
print("Precision:", single_precision)
print("Recall:", single_recall)
print(f"AUC score: {single_auc_score}")
print("F1 score:", single_f1)
print("Accuracy:", single_accuracy)
# Out:
# Single
# Precision: 0.7777777777777778
# Recall: 1.0
# AUC score: 0.9685714285714285
# F1 score: 0.875
# Accuracy: 0.8857142857142857

# %%
# 결과 출력
print("Double")
print("Precision:", double_precision)
print("Recall:", double_recall)
print(f"AUC score: {double_auc_score}")
print("F1 score:", double_f1)
print("Accuracy:", double_accuracy)
# Out:
# Double
# Precision: 0.8088235294117647
# Recall: 0.7746478873239436
# AUC score: 0.9255970606246173
# F1 score: 0.7913669064748201
# Accuracy: 0.7928571428571428

# %%
# Single confusion matrix 시각화
plt.figure(figsize=(8, 6))
sns.heatmap(single_conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Double confusion matrix 시각화
plt.figure(figsize=(8, 6))
sns.heatmap(double_conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Precision-Recall curve 그리기
s_precision, s_recall, _ = precision_recall_curve(Y_single_test, single_Y_prob)
d_precision, d_recall, _ = precision_recall_curve(Y_double_test, double_Y_prob)
plt.figure(figsize=(8, 6))
plt.plot(s_recall, s_precision, color='darkorange', label='PR curve of Single type')
plt.plot(d_recall, d_precision, color='darkgreen', label='PR curve of Double type')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower right')
plt.show()

# ROC AUC curve 그리기
s_fpr, s_tpr, _ = roc_curve(Y_single_test, single_Y_prob)
d_fpr, d_tpr, _ = roc_curve(Y_double_test, double_Y_prob)
single_roc_auc = auc(s_fpr, s_tpr)
double_roc_auc = auc(d_fpr, d_tpr)
plt.figure(figsize=(8, 6))
plt.plot(s_fpr, s_tpr, color='darkorange', lw=2, label='ROC curve of Single type (AUC = %0.2f)' % single_roc_auc)
plt.plot(d_fpr, d_tpr, color='darkgreen', lw=2, label='ROC curve of Double type (AUC = %0.2f)' % double_roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %%
# 테스트 데이터에 대한 예측 결과를 얻기 위해 모델 사용
single_predictions = single_model.predict(X_single_test)

# 이동 평균을 계산하여 예측값 부드럽게 만들기
single_smoothed_predictions = np.convolve(single_predictions.squeeze(), np.ones(6)/6, mode='same')

# 테스트 데이터에 대한 예측 결과를 바이너리 형태로 변환
single_binary_predictions = (single_smoothed_predictions > 0.5).astype(int)
# Out:
# 6/6 [==============================] - 0s 2ms/step

# %%
# 테스트 데이터에 대한 예측 결과를 얻기 위해 모델 사용
double_predictions = double_model.predict(X_double_test)

# 이동 평균을 계산하여 예측값 부드럽게 만들기
double_smoothed_predictions = np.convolve(double_predictions.squeeze(), np.ones(6)/6, mode='same')

# 테스트 데이터에 대한 예측 결과를 바이너리 형태로 변환
double_binary_predictions = (double_smoothed_predictions > 0.5).astype(int)
# Out:
# 5/5 [==============================] - 0s 1ms/step

# %%
# 0에서 1로 바뀌는 구간에서 줄넘기 개수 카운트
single_jump_count = np.sum(np.diff(single_binary_predictions.flatten()) > 0)

# %%
# 0에서 1로 바뀌는 구간에서 줄넘기 개수 카운트
double_jump_count = np.sum(np.diff(double_binary_predictions.flatten()) > 0)

# %%
# 테스트 데이터의 점프수
print(f'Predicted Jump Count for single: {single_jump_count}')
# Out:
# Predicted Jump Count for single: 10

# %%
# 테스트 데이터의 점프수
print(f'Predicted Jump Count for double: {double_jump_count}')
# Out:
# Predicted Jump Count for double: 8

# %%
# Single type에 대한 예측 결과

plt.plot(Y_single_test, label='Actual')
plt.plot(single_binary_predictions.flatten(), label='Predicted')
plt.title('Actual vs Predicted for single type')
plt.xlabel('Data Point')
plt.ylabel('Label')
plt.legend()
plt.show()

# %%
# Single type에 대한 예측 결과

plt.plot(Y_double_test, label='Actual')
plt.plot(double_binary_predictions.flatten(), label='Predicted')
plt.title('Actual vs Predicted for double type')
plt.xlabel('Data Point')
plt.ylabel('Label')
plt.legend()
plt.show()
